# %%
import numpy as np
import cv2 as cv
import mediapipe as mp
import os
from matplotlib import pyplot as plt
import time
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# Out:
# objc[56587]: Class CaptureDelegate is implemented in both /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x1547765a0) and /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_videoio.3.4.16.dylib (0x150d6c860). One of the two will be used. Which one is undefined.
# objc[56587]: Class CVWindow is implemented in both /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x1547765f0) and /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x1113b0a68). One of the two will be used. Which one is undefined.
# objc[56587]: Class CVView is implemented in both /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x154776618) and /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x1113b0a90). One of the two will be used. Which one is undefined.
# objc[56587]: Class CVSlider is implemented in both /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x154776640) and /Users/d_f_i/miniconda3/envs/tensorflow/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x1113b0ab8). One of the two will be used. Which one is undefined.

# %%
DATA_PATH = os.path.join('Dataset')
#print(os.listdir(key_points))
actions = np.array(['Thank_you', 'Hello', 'Good', 'Goodbye', 'Yes'])

label_map = {label:num for num, label in enumerate(actions)}

# %%
sequences, labels = [], []

for action in os.listdir(DATA_PATH):
    if not os.path.isdir(os.path.join(DATA_PATH, action)):
        continue
    #print(action)
    for sequence in os.listdir(os.path.join(DATA_PATH, action)):
        if not os.path.isdir(os.path.join(DATA_PATH, action, sequence)):
            continue
        #print(f'\t{sequence}')
        window = []
        for frame_num in range(30):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
x = np.array(sequences)
y = to_categorical(labels).astype(int)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import load_model as load_model

# %%
model_path = os.path.join('AI_models', 'actionsv0.3.1-5 signs.h5')
model = load_model(model_path)
#model.summary()
# Out:
# Metal device set to: Apple M1
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
def mediapipe_detection(image, model):
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv.cvtColor(image, cv.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

def draw_landmarks(image, results):
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1))
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2))
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2))
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))
   
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )
def extract_keypoints(results):
	pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
	face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
	left_hand = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
	right_hand = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
	return np.concatenate([pose, face, left_hand, left_hand])

# %%
from scipy import stats
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), (117,245,16), -1)
        cv.putText(output_frame, actions[num], (0, 85+num*40), cv.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2, cv.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils
cap = cv.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        #draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        image = cv.flip(image, 1)
        print(int(cap.get(5)))
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
        
        cv.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv.putText(image, ' '.join(sentence), (3,30), 
                       cv.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv.LINE_AA)
        
        # Show to screen
        cv.imshow('BSL Translator-v0.3.1', image)

        # Break gracefully
        if cv.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv.destroyAllWindows()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 2023-04-25 20:15:57.156399: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 0s 474ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 199ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 194ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 201ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 205ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 194ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 200ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 197ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 199ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 199ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 194ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 192ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 192ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 194ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 170ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 192ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 198ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 170ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 167ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 169ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 170ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 192ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 192ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 201ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 195ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 192ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 197ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 173ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 189ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 190ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 198ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 188ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 191ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 198ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 194ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 176ms/step
# Goodbye
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 183ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 177ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 199ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 193ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 181ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 262ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 187ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 203ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 180ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 185ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 204ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 178ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 171ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 182ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 174ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 186ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 175ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 179ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 184ms/step
# Thank_you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 30
# 1/1 [==============================] - 0s 172ms/step
